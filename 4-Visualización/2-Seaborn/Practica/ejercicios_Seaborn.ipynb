# %%
#TODO hacer apuntes

# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# # 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline #esto antes se usaba porque cuando se cerraba el notebook las imagenes se cerraban, asi se quedan. Ahora no se usa
# Out:
# UsageError: unrecognized arguments: #esto antes se usaba porque cuando se cerraba el notebook las imagenes se cerraban, asi se quedan. Ahora no se usa

# %% [markdown]
# # 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
df = pd.read_csv('/Users/administrador/Documents/Bootcamp/Data_Analyst/4-Visualización/2-Seaborn/Practica/data/Pokemon.csv', encoding= "latin1", index_col="#") #se usa el encoding="latin1" porque sino da error porque hay algun dato en el dataset que tiene un simbolo raro que no esta en utf-8
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# max    140.000000    3.000000

# %% [markdown]
# # 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# # 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# # Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(x='Attack', y='Defense', data=df); #el sombreado es el margen de confianza

# %% [markdown]
# # 6. No queremos ver la línea recta de la regresión lineal.
# # prueba a añadir fit_reg a falso

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False);

# %% [markdown]
# # 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# # Que el hue sea el Stage

# %%
df["Stage"].unique()
# Out:
# array([1, 2, 3])

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue="Stage");

# %%
sns.lmplot(x='Attack', y='Defense', data=df, hue="Stage");

# %% [markdown]
# # 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue="Stage");
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %% [markdown]
# # 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(y=df['Attack']);

# %%
sns.boxplot(data=df[["Attack", "Defense", "Speed"]]);

# %% [markdown]
# # 10. No nos interesan las columnas Total, Stage ni Legendary
# # Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df2 = df.drop(columns=['Stage', "Total", "Legendary"])
sns.boxplot(df2);

# %% [markdown]
# # 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df["Type 1"].nunique()
# Out:
# 15

# %%
# Out:
# 15

# %% [markdown]
# # 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
df_filtrado = df[df["Type 1"].isin(["Grass", "Fire", "Water"])]
df_filtrado.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
df_filtrado=df.query("Type1 in ['Grass', 'Fire', 'Water']")
df_filtrado.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/scope.py:198, in Scope.resolve(self, key, is_local)
#     197 if self.has_resolvers:
# --> 198     return self.resolvers[key]
#     200 # if we're here that means that we have no locals and we also have
#     201 # no resolvers
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/collections/__init__.py:1004, in ChainMap.__getitem__(self, key)
#    1003         pass
# -> 1004 return self.__missing__(key)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/collections/__init__.py:996, in ChainMap.__missing__(self, key)
#     995 def __missing__(self, key):
# --> 996     raise KeyError(key)
#
# KeyError: 'Type_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/scope.py:209, in Scope.resolve(self, key, is_local)
#     205 try:
#     206     # last ditch effort we look in temporaries
#     207     # these are created when parsing indexing expressions
#     208     # e.g., df[df > 0]
# --> 209     return self.temps[key]
#     210 except KeyError as err:
#
# KeyError: 'Type_1'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_filtrado=df.query("Type_1 in ['Grass', 'Fire', 'Water']")
#       2 df_filtrado.head()
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/eval.py:353, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     344 # get our (possibly passed-in) scope
#     345 env = ensure_scope(
#     346     level + 1,
#     347     global_dict=global_dict,
#    (...)
#     350     target=target,
#     351 )
# --> 353 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     355 # construct the engine and evaluate the parsed expression
#     356 eng = ENGINES[engine]
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:456, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     454 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     455     if left is None:
# --> 456         left = self.visit(node.left, side="left")
#     457     if right is None:
#     458         right = self.visit(node.right, side="right")
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/ops.py:85, in Term.__init__(self, name, env, side, encoding)
#      83 tname = str(name)
#      84 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 85 self._value = self._resolve_name()
#      86 self.encoding = encoding
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/ops.py:109, in Term._resolve_name(self)
#     104 if local_name in self.env.scope and isinstance(
#     105     self.env.scope[local_name], type
#     106 ):
#     107     is_local = False
# --> 109 res = self.env.resolve(local_name, is_local=is_local)
#     110 self.update(res)
#     112 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/computation/scope.py:211, in Scope.resolve(self, key, is_local)
#     209     return self.temps[key]
#     210 except KeyError as err:
# --> 211     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'Type_1' is not defined

# %% [markdown]
# # 13. Usa un estilo 'whitegrid'

# %%
sns.set_style("whitegrid")

# %% [markdown]
# # 14. Pinta diagramas de violín con el DataFrame

# %%
plt.figure(figsize=(10,5)) #redimensiona (tiene que ir antes de la figura)
sns.violinplot(x="Type 1", y="Attack", data=df);
plt.ylim([0,200]) #le pone límite a los ejes (tiene que ir después de la figura)
# Out:
# (0.0, 200.0)

# %% [markdown]
# # 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colors = ['#78C850', '#F08030',  '#6890F0']

# %% [markdown]
# # 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(x="Type 1", y="Attack", data=df, palette=colors);

# %% [markdown]
# # 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# # Para ver esto, usamos el swarmplot.
# # Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x="Type 1", y="Attack", data=df, palette=colors);
# Out:
# /var/folders/r1/hd_91nzn1yb8kh1vq1c7gt2w0000gn/T/ipykernel_992/1615167925.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="Type 1", y="Attack", data=df, palette=colors);
# /var/folders/r1/hd_91nzn1yb8kh1vq1c7gt2w0000gn/T/ipykernel_992/1615167925.py:2: UserWarning:
# The palette list has fewer values (3) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(x="Type 1", y="Attack", data=df, palette=colors);

# %% [markdown]
# # 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# # Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9
# # Pon un título con pyplot (como siempre)

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x="Type 1", y="Attack", data=df, palette=colors, inner=None, alpha=0.1); #inner le quita lo de dentro de los violines
sns.swarmplot(x="Type 1", y="Attack", data=df, color="k", alpha=0.9); #alpha es la tranasparencia
plt.title("Attack vs Type 1"); #le pone un título

# %% [markdown]
# # 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# # Dado un DataFrame, melt recibe varios parámetros:
# # * qué columnas del DataFrame se quedan igual
# # * qué nombres de columnas del dataframe pasan a ser una columna nueva
# # * cómo queremos llamar esas nuevas columnas
#
# # Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# # 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# # Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# # Escribimos df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
melted = df.melt(id_vars=['Name', 'Type 1'], value_vars=['HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Stage'], var_name='Melted variables')

# %%
melted[melted["Name"]=="Bulbasaur"]
# Out:
#           Name Type 1 Melted variables  value
# 0    Bulbasaur  Grass               HP     45
# 151  Bulbasaur  Grass           Attack     49
# 302  Bulbasaur  Grass          Defense     49
# 453  Bulbasaur  Grass          Sp. Atk     65
# 604  Bulbasaur  Grass          Sp. Def     65
# 755  Bulbasaur  Grass            Speed     45
# 906  Bulbasaur  Grass            Stage      1

# %%
# Out:
#            Name Type 1 Melted variables  value
# 0     Bulbasaur  Grass               HP     45
# 1       Ivysaur  Grass               HP     60
# 2      Venusaur  Grass               HP     80
# 3    Charmander   Fire               HP     39
# 4    Charmeleon   Fire               HP     58
# ..          ...    ...              ...    ...
# 359    Gyarados  Water            Stage      2
# 360      Lapras  Water            Stage      1
# 361    Vaporeon  Water            Stage      2
# 362     Flareon   Fire            Stage      2
# 363     Moltres   Fire            Stage      1
#
# [364 rows x 4 columns]

# %% [markdown]
# # 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(x="Melted variables", y="value", data=melted[melted["Type 1"].isin(["Grass", "Fire", "Water"])], hue="Type 1");
# Out:
# /Users/administrador/.pyenv/versions/3.11.1/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/administrador/.pyenv/versions/3.11.1/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# # En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# # Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# # Usando plt
# # fija el límite del eje Y entre 0 y 200
# # fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x='Melted variables', y='value', data = melted[melted['Type 1'].isin(['Grass','Fire','Water'])],hue='Type 1', dodge=True) #dodge es para separar los valores, es como quitar el melted
plt.ylim(0,200)
plt.legend(bbox_to_anchor=(1,1), loc=2) #sirve para la leyende
# Out:
# /Users/administrador/.pyenv/versions/3.11.1/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 60.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/administrador/.pyenv/versions/3.11.1/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# # Lo importante es que Seaborn y Pyplot conviven bien juntos

# %% [markdown]
# # 23. Mapas de calor
# # Calcula las correlaciones del primer DataFrame original df
# # Pista: las correlaciones se calculan con el método corr()
# # Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
correlation = df[["Attack", "Defense", "Total"]].corr()
correlation[correlation["Attack"]>0.5]
# Out:
#           Attack   Defense     Total
# Attack  1.000000  0.491965  0.670939
# Total   0.670939  0.508694  1.000000

# %%
sns.heatmap(correlation, annot=True);

# %% [markdown]
# # ¿la correlación entre qué valores se encuentra?
# # la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# # Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# # Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %% [markdown]
# # 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.displot(df["Defense"], kde=True);

# %% [markdown]
# # 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# # Usa un sns.countplot
# # Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(x="Type 1", data=df);
plt.xticks(rotation=-45, fontsize=10); #sirve para modificar los ejes

# %% [markdown]
# # 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# # y divide los colores según el Type 2

# %%
sns.catplot(x="Type 1", y="Defense", data=df, hue= "Type 2", col="Legendary"); #el col me separa en 2, en legendario y no legendario

# %%
# Out:
#        Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 50  Diglett  Ground    NaN    265  10      55       25       35       45
#
#     Speed  Stage  Legendary
# #
# 50     95      1      False

# %% [markdown]
# # 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# # Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %% [markdown]
# # 28. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original
