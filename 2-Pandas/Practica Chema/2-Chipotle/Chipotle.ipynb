# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", delimiter="\t")

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df["item_price"] = df["item_price"].apply(lambda x: x.replace("$", "")).astype(float)
df["item_price"]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %% [markdown]
# # Name of the max valued product

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df["item_price_unit"] = df["item_price"]/df["quantity"]

# %%
df[df["item_price_unit"] == df["item_price_unit"].max()]
# Out:
#       order_id  quantity            item_name  \
# 281        123         2     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# ...

# %%
df[df["item_price_unit"] == df["item_price_unit"].max()]["item_name"].unique()
# Out:
# array(['Steak Salad Bowl', 'Carnitas Salad Bowl', 'Barbacoa Salad Bowl'],
#       dtype=object)

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
df[df["item_price_unit"]>10][["item_name","item_price_unit"]]
# Out:
#                item_name  item_price_unit
# 5           Chicken Bowl            10.98
# 7          Steak Burrito            11.75
# 13          Chicken Bowl            11.25
# 23       Chicken Burrito            10.98
# 39         Barbacoa Bowl            11.75
# ...                  ...              ...
# 4610       Steak Burrito            11.75
# 4611      Veggie Burrito            11.25
# 4617       Steak Burrito            11.75
# 4618       Steak Burrito            11.75
# 4619  Chicken Salad Bowl            11.25
#
# [1034 rows x 2 columns]

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
df[["item_name","item_price_unit"]]
# Out:
#                                   item_name  item_price_unit
# 0              Chips and Fresh Tomato Salsa             2.39
# 1                                      Izze             3.39
# 2                          Nantucket Nectar             3.39
# 3     Chips and Tomatillo-Green Chili Salsa             2.39
# 4                              Chicken Bowl             8.49
# ...                                     ...              ...
# 4617                          Steak Burrito            11.75
# 4618                          Steak Burrito            11.75
# 4619                     Chicken Salad Bowl            11.25
# 4620                     Chicken Salad Bowl             8.75
# 4621                     Chicken Salad Bowl             8.75
#
# [4622 rows x 2 columns]

# %%
df[["item_name","item_price_unit"]].set_index("item_name")
# Out:
#                                        item_price_unit
# item_name
# Chips and Fresh Tomato Salsa                      2.39
# Izze                                              3.39
# Nantucket Nectar                                  3.39
# Chips and Tomatillo-Green Chili Salsa             2.39
# Chicken Bowl                                      8.49
# ...                                                ...
# Steak Burrito                                    11.75
# Steak Burrito                                    11.75
# Chicken Salad Bowl                               11.25
# Chicken Salad Bowl                                8.75
# Chicken Salad Bowl                                8.75
#
# [4622 rows x 1 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#    item_price_unit
# 0             2.39
# 1             3.39
# 2             3.39
# 3             2.39
# 4             8.49

# %%
df.sort_values("item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %% [markdown]
# V1

# %%
df.loc[df["item_price"] == df["item_price"].max()]["quantity"].values[0]
# Out:
# 15

# %% [markdown]
# V2

# %%
df[df["item_price"] == df["item_price"].max()].index
# Out:
# Int64Index([3598], dtype='int64')

# %%
df.iloc[3598]["quantity"]
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
df.loc[df["item_name"] == "Veggie Salad Bowl"]["quantity"].sum()
# Out:
# 18

# %%
df.loc[df["item_name"] == "Veggie Salad Bowl"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 186 to 4573
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            18 non-null     int64
#  1   quantity            18 non-null     int64
#  2   item_name           18 non-null     object
#  3   choice_description  18 non-null     object
#  4   item_price          18 non-null     float64
#  5   item_price_unit     18 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1008.0+ bytes

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
df[df["quantity"]>1].groupby("item_name")["quantity"].count().loc["Canned Soda"]
# Out:
# 20

# %%
df[df["quantity"]>1].groupby("item_name")["quantity"].count().iloc[4]
# Out:
# 20

# %%
df[df["quantity"]>1].groupby("item_name").count().loc["Canned Soda"]
# Out:
# order_id              20
# quantity              20
# choice_description    20
# item_price            20
# item_price_unit       20
# Name: Canned Soda, dtype: int64
